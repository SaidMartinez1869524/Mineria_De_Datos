# %% [markdown]
# <a href="https://colab.research.google.com/github/SaidMartinez1869524/Mineria_De_Datos/blob/main/Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Examen**
#
# Grupo 2 Miércoles de 7:00pm-10:00pm
#
# 1869524 Luis said Martinez Hernandez
#
# 1817336 Edmundo Isai Ibarra Cavazos
#
# #Instrucciones:Parte 1 (Programación Básica de Python):

# %% [markdown]
# 1- Haz una función que te imprima listas de números enteros aleatorios con cantidad de 5, 10, 15 elementos

# %%
import random
from random import randint 
na1 = [randint(1,100) for _ in range(5)]
print("Lista 1",na1)
import random
from random import randint 
na2 = [randint(1,100) for _ in range(10)]
print("Lista 2",na2)
import random
from random import randint 
na3 = [randint(1,100) for _ in range(15)]
print("Lista 3",na3)
# Out:
# Lista 1 [94, 3, 62, 80, 67]
# Lista 2 [19, 40, 16, 61, 9, 61, 94, 44, 23, 22]
# Lista 3 [67, 65, 19, 37, 32, 17, 90, 83, 64, 15, 95, 57, 89, 16, 24]

# %% [markdown]
# 2.Con la función que generaste toma la lista de 15, y haz una función que te indique cual de los números es el mayor, y otra que te indique cual es el menor.

# %%
list=na3
mayor=max(list)
minimo=min(list)
print("El numero mayor de la lista 3 es:",mayor)
print("El numero minimo de la lista 3 es:",minimo)
# Out:
# El numero mayor de la lista 3 es: 95
# El numero minimo de la lista 3 es: 15

# %% [markdown]
# 3.Toma las listas y ordénalas de mayor a menor, y de menor a mayor

# %%
na11=sorted(na1)
na21=sorted(na2)
na31=sorted(na3)
na12=sorted(na1,reverse=True)
na22=sorted(na2,reverse=True)
na32=sorted(na3,reverse=True)
print("Numeros ordenados de mayor a menor")
print("Lista 1:",na11)
print("Lista 2:",na21)
print("Lista 3:",na31)
print("Numeros ordenados de menor a mayor")
print("Lista 1:",na12)
print("Lista 2:",na22)
print("Lista 3:",na32)
# Out:
# Numeros ordenados de mayor a menor
# Lista 1: [3, 62, 67, 80, 94]
# Lista 2: [9, 16, 19, 22, 23, 40, 44, 61, 61, 94]
# Lista 3: [15, 16, 17, 19, 24, 32, 37, 57, 64, 65, 67, 83, 89, 90, 95]
# Numeros ordenados de menor a mayor
# Lista 1: [94, 80, 67, 62, 3]
# Lista 2: [94, 61, 61, 44, 40, 23, 22, 19, 16, 9]
# Lista 3: [95, 90, 89, 83, 67, 65, 64, 57, 37, 32, 24, 19, 17, 16, 15]

# %% [markdown]
# 4.Haz una sola lista que contenga todos los elementos pares de las 3 primeras listas.

# %%
list=na1
for number in list:
  if number%2== 0:
    print("Lista 1",number)

list=na2
for number in list:
  if number%2== 0:
    print("Lista 2",number)

list=na3
for number in list:
  if number%2== 0:
    print("Lista 3",number)
# Out:
# Lista 1 94
# Lista 1 62
# Lista 1 80
# Lista 2 40
# Lista 2 16
# Lista 2 94
# Lista 2 44
# Lista 2 22
# Lista 3 32
# Lista 3 90
# Lista 3 64
# Lista 3 16
# Lista 3 24

# %% [markdown]
# 5.Reemplazar todos los números imparesdel arreglode 15 elementos del ejercicio 1.)con un -1.

# %%
AB=[]
for i in na3:
  if(i%2==0):
    AB.append(i)
  else:
    AB.append(-1)
print("Numeros impares sustituidos por -1 de la lista 3 es:\n",AB)
# Out:
# Numeros impares sustituidos por -1 de la lista 3 es:
#  [-1, -1, -1, -1, 32, -1, 90, -1, 64, -1, -1, -1, -1, 16, 24]

# %% [markdown]
# 6.Haz una función que te permita hacer conversiones de grados Celsius a Fahrenheit.

# %%
def CelstoFah(celsius):
  "Convierte grados Celsius en grados Fahrenheit."
  return (celsius * 9.0/5.0) + 32

print("9 grados celsisu son :",CelstoFah(9),"Grados Fahrenheit",)
# Out:
# 9 grados celsisu son : 48.2 Grados Fahrenheit

# %% [markdown]
# 7.Hacer relaciones entre los datos de las siguientes listas. El resultado deberá ser una lista con los elementos que se repitan en ambas listas.
#
# a.= 1, 2, 3, 9, 3, 4, 3, 4, 5, 6, 11
#
# b.= 10, 6, 5, 7, 11, 12, 4, 5, 9, 66

# %%
a=[1,2,3,9,3,4,3,4,5,6,11]
b=[10,6,5,7,11,12,4,5,9,66]

A=[]
val=0
for i in a:
  val=0
  for j in b:
    if(i==j):
      val=val+1
      for k in A:
        if(i==k):
          val=0
  if(val>0):
    A.append(i)
print("Los numeros repetidos en a y b son:\n",A)
# Out:
# Los numeros repetidos en a y b son:
#  [9, 4, 5, 6, 11]

# %% [markdown]
# 8.De las técnicas que vimos en clase, describe 2. Para que son, como se utilizan y da dos ejemplos pequeños.
#
# 1-Los patrones secuenciales son aquellos qué en la minería ocurren frecuentemente, el objetivo de este es buscar asociaciones de forma en que si un evento sucede en un tiempo determinado sucederá en otro tiempo y en otro, dónde tienen la característica de que el orden debe ser importante también debe ser una lista de datos qué ocurren frecuentemente
# Uno de los ejemplos serían secuencias de ADN determinar si un evento es decir una enfermedad pasa en un determinado tiempo entonces nada otra enfermedad sucederá en otro tiempo
# Otro ejemplo puede ser qué tipo de artículo es más probable que compren durante un tiempo determinado tomando en cuenta el patrón de secuencias que se ha tomado en nuestra base de datos
#
# 2-La técnica de árboles de decisión se utiliza para mostrar en alistar las opciones disponibles para la toma de una decisión, de los cuales son más que nada informativos, uno de los ejemplos en el que se pueda aplicar los árboles de decisión es en ciencias de la computación en el diseño de aplicaciones informativas lo cual nos indican las acciones a realizar en función de un valor o varias variables, otro de los ejemplos en árboles de decisión sería la economía que generalmente se utiliza para predecir probabilidades para alcanzar un resultado en función de unas variables de entrada como edad sexo demografía o ingresos que se den

# %% [markdown]
# #**Parte 2**

# %% [markdown]
# Introducción;
#
# Hoy en dia la eduación se a echo un factor importante para el desarollo de las personas, tanto economicamente, moralmente y socialmente hablando,es aqui cuando el gobierno da su punto de vista, queriendo mejorar la calidad de vida economica de los habitantes, para esto decide abordar el problema desde la eduación, ,pero asi como el factor del estudio fue aumentando hoy en dia, hay ciertos lugares o ciertos grupos de peronas que se les a complicado mas el echo de tener una educación, con el fin de la infromación obtenida, se planteara la idea de dar una beca por parte del gobierno buscando los diferentes factores a considerar para la selección de estos, tomando en cuenta como los puntajes compuestos y totales, los ingresos de los padres y a la vez este factor se debe comparar con el grado de estudio de los padres para asi poder confirmar que el estudio superior ayuda al desarrollo enconomico y social en los alumnos
#
# Todo esto para en el futuro el ingreso del pais vaya en aumento, asi como la pobreza en disminución , la eudación sea algo primoridal y normal que la gente tenga que hacer
#
#
#
#
# Objetivos;
#
# Principal;Decidir los factores a escoger para la selección de una beca ecónomica para los alumnos
#
# Secundario; Ver durante cuanto tiempo aproximadamente se le puede brindar la beca a un estudiante, de acuerdo a el termino de sus estudios
#
# Tercicario; Seleccionar al 10% de la población para la beca
# Student Graduation:
#
# URL:https://www.kaggle.com/christinarobert/student-graduation-rate

# %% [markdown]
# LIMPIEZA DE DATOS;

# %%
import pandas as pd
import numpy as np
import json 
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-91ac5b20-d963-42de-bf5d-40b618003512" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91ac5b20-d963-42de-bf5d-40b618003512">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving graduation_rate.csv to graduation_rate.csv
# ...

# %%
df=pd.read_csv("graduation_rate.csv")
print(df) 
print(df.shape) 
print(df.head) 
print(df.tail)
print(df.columns)
# Out:
#      ACT composite score  SAT total score  ... college gpa  years to graduate
# 0                     30             2206  ...         3.8                  3
# 1                     26             1953  ...         2.7                  9
# 2                     28             2115  ...         3.3                  5
# 3                     33             2110  ...         3.5                  4
# 4                     30             2168  ...         3.6                  4
# ..                   ...              ...  ...         ...                ...
# 995                   30             1967  ...         3.5                  6
# 996                   28             2066  ...         3.5                  4
# 997                   27             1971  ...         3.7                  5
# 998                   30             2057  ...         3.6                  3
# 999                   29             2054  ...         3.3                  5
#
# [1000 rows x 7 columns]
# (1000, 7)
# ...

# %%
df = df.rename(columns = {'ACT composite score':'Puntaje compuesto'})
df = df.rename(columns = {'SAT total score':'Puntaje total'})
df = df.rename(columns = {'parental level of education':'Estudios de padre'})
df = df.rename(columns = {'parental income':'Ingresos de padres'})
df = df.rename(columns = {'high school gpa':'gpa escuela'})
df = df.rename(columns = {'college gpa.':'gpa universidad'})
df = df.rename(columns = {'years to graduate':'Años por graduarse'})
df
# Out:
#      Puntaje compuesto  Puntaje total  ... college gpa  Años por graduarse
# 0                   30           2206  ...         3.8                   3
# 1                   26           1953  ...         2.7                   9
# 2                   28           2115  ...         3.3                   5
# 3                   33           2110  ...         3.5                   4
# 4                   30           2168  ...         3.6                   4
# ..                 ...            ...  ...         ...                 ...
# 995                 30           1967  ...         3.5                   6
# 996                 28           2066  ...         3.5                   4
# 997                 27           1971  ...         3.7                   5
# 998                 30           2057  ...         3.6                   3
# 999                 29           2054  ...         3.3                   5
#
# [1000 rows x 7 columns]

# %%
df.to_csv("Becas.csv")
df = pd.read_csv("/content/Becas.csv")
df
# Out:
#      Unnamed: 0  Puntaje compuesto  ...  college gpa Años por graduarse
# 0             0                 30  ...          3.8                  3
# 1             1                 26  ...          2.7                  9
# 2             2                 28  ...          3.3                  5
# 3             3                 33  ...          3.5                  4
# 4             4                 30  ...          3.6                  4
# ..          ...                ...  ...          ...                ...
# 995         995                 30  ...          3.5                  6
# 996         996                 28  ...          3.5                  4
# 997         997                 27  ...          3.7                  5
# 998         998                 30  ...          3.6                  3
# 999         999                 29  ...          3.3                  5
#
# [1000 rows x 8 columns]

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# Aqui se puede ver que la base de datos consta de 8 columnas de 1000 datos, de las cuales las que nos interesan trabajar con ellas son:
#
#
#
#
# * ACT composite score
# * SAT total score
# * Parental level of education
# * Parental income
# * years to graduate
#
# Puesto los factores que debemos analizar son los de; ingresos de padres, asi como la confimación de que gracias a su nivel de estudio sus ingresos fueron mayores, asi como el puntaje de los alumnos

# %% [markdown]
# Despues se bucaron datos nulos y se descubrio que no habia ninguno

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Puntaje compuesto     0
# Puntaje total         0
# Estudios de padre     0
# Ingresos de padres    0
# gpa escuela           0
# college gpa           0
# Años por graduarse    0
# dtype: int64

# %% [markdown]
# Una vez obtenido nuestra base de datos , efectuaremos un mapa de correlación para ver la correlación que hay entre estos datos

# %%
#Mapa de correlación 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
f,ax=plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# Se puede notar que hay una gran relacion entre el puntaje total junto con la escuela y la puntuación compuesta, lo que nos quiere decir que los datos van muy tomados de la mano, lo cual podremos voporbar mediante una grafica , tambien pudimos notar que es una relación muy negativa entre el salario de los padres como con los años por graduarse que era de esperarse

# %% [markdown]
# Una vez analizado toda la base de datos, de lo que esta compuesta y que factores nos interezan, procedemos a eliminar los datos que no nos sirven para el proposito de esta base de datos

# %%
df.drop(columns = "gpa escuela", inplace = True)
df.drop(columns = "Unnamed: 0", inplace = True)
df.drop(columns = "college gpa", inplace = True)
df.head()
# Out:
#    Puntaje compuesto  Puntaje total  ... Ingresos de padres  Años por graduarse
# 0                 30           2206  ...              94873                   3
# 1                 26           1953  ...              42767                   9
# 2                 28           2115  ...              46316                   5
# 3                 33           2110  ...              52370                   4
# 4                 30           2168  ...              92665                   4
#
# [5 rows x 5 columns]

# %% [markdown]
# Visualizción;

# %% [markdown]
# Primeramente para ir analizando a qué estudiantes se les ofrecerá la beca de los 100 seleccionados (10%)se tomará en cuenta las primeras dos columnas qué son de puntaje total y puntaje compuesto(visto en el mapa de correlación), esto para ver si se relaciona el hecho de que los alumnos que obtuvieron menor puntaje compuesto, efectivamente en el puntaje total sería similar, asi para poder seleccionar a los alumnos de mayor puntaje tanto en puntaje compuesto como en el total

# %%
students_filepath="Becas.csv"
student_data=pd.read_csv(students_filepath)

# %%
#Grafica 1
plt.figure(figsize=(10,6))
plt.title("puntaje compuesto- puntaje total ")
sns.barplot(x=student_data['Puntaje compuesto'],y=student_data['Puntaje total'],)
sns.set_style("dark")
plt.xlabel("Puntaje compuesta")
plt.ylabel("puntaje total ")
# Out:
# Text(0, 0.5, 'puntaje total ')

# %% [markdown]
# Una vez analizando la gráfica y viendo que el puntaje compuesto es similar al puntaje total es decir que los alumnos que obtuvieron puntaje total alto obtuvieron el mismo puntaje compuesto alto tomaremos en cuenta las calificaciones más altas es decir las primeras 100 calificaciones, como se moestro en la grafica de correlación
# Se debe mencionar que hubo un dato atipico en el cual es el 19 en el puntaje compuesto en donde se ve claramente porque no tiene variación, puesto que solo una persona contesto

# %%
#Grafica 2
iris_filepath ="Becas.csv"
iris_data = pd.read_csv(iris_filepath, index_col="Puntaje total")

# %%
# Histogram 
sns.distplot(a=iris_data['Puntaje compuesto'], kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# En el siguiente histograma lo que se puso consideración para lo siguiente fueron las calificaciones de los alumnos en lo cual se puede notar que la gran parte estuvo entre calificación es de 25 a 32 y muy pocos obtuvieron menores calificaciones así como muy pocos obtuvieron mayor a 35 de puntaje

# %%
# Grafica 3
sns.distplot(a=iris_data['Ingresos de padres'], kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Una vez analizado las calificaciones promedio de los alumnos que rondan entre 25 y 32 también es importante ver los ingresos de los padres qué en general rondan entre los 40,000 y 100,000 de lo cual es importante mencionar puesto que también se estarán proporcionando becas a los alumnos que aunque no estuvieron en las mejores 100 calificaciones, pueden obtener algún otro tipo te beca por escasos recursos

# %%
# grafica 4
sns.distplot(a=iris_data['Años por graduarse'], kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Los puntos también importantes aclarar es la cantidad de años en la que se encuentran los estudiantes para poder graduarse de lo cual cómo podemos observar sería aproximadamente entre 3 y 6 años esto quiere decir que el gobierno les tendría que ofertar esa beca durante un lapso promedio entre 3 y 6 años

# %%
#Grfaica 5
plt.figure(figsize=(10,6))
plt.title("puntaje compuesto- puntaje total ")
sns.barplot(x=student_data['Puntaje compuesto'],y=student_data['Ingresos de padres'],)
sns.set_style("dark")
plt.xlabel("Puntaje compuesta")
plt.ylabel("puntaje total ")
# Out:
# Text(0, 0.5, 'puntaje total ')

# %% [markdown]
# Una vez comparando estos datos en la gráfica podemos observar que conforme va aumentando el ingreso de los padres va subiendo ligeramente la puntuación de los estudiantes esto es un punto importante a reconocer puesto que se planea ayudar a los jóvenes de escasos recursos seria un factor importante

# %%
#Grafica 6
insurance_filepath = "Becas.csv"
insurance_data = pd.read_csv(insurance_filepath)

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=insurance_data['Ingresos de padres'], y=insurance_data['Estudios de padre'])

# %% [markdown]
# Tambien una vez comparando el ingreso de los padres con la puntuación compuesta de los estudiantes se puede ver que el aumento es ligeramente notorio, por lo cual es importante aclarar y verificar ue la mayoria de los padres de los estudiantes tienen un ingreso mayor mientras su grado de estudio sea aún mayor

# %%
#Grafica 7
sns.scatterplot(x=insurance_data['Puntaje compuesto'], y=insurance_data['Ingresos de padres'], hue=insurance_data['Estudios de padre'])

# %% [markdown]
# Ahora bien una vez analizando los datos individualmente se pudo efectuar está en dónde se hace comparación de las calificaciones el ingreso de los padres y el tipo de trabajo lo cual una vez analizándolo se puede notar que conforme va las calificaciones van subiendo los ingresos de los padres van en aumento así como va aumentando el nivel de educación en el que se prepararon los padres, esto quiere decir que los alumnos que tengan mayores calificaciones tienen una tendencia un mayor a qué los padres tengan mayor nivel económico, lo cual sería un factor negativo a considerar para efectuar las becas, en la que se piden efectuar varias comparaciones, tanto económicas como académicas

# %% [markdown]
# Conclusión:
#
# Durante el proceso de la técnica de limpieza de datos y visualización de datos pudimos observar qué No se encontraron valores nulos también qué es una gráfica compuesta de 7 columnas de 1000 datos pero nosotros solo nos interesamos en exactamente cuatro por lo que se eliminaron esas tres restantes también se pudo ver que hay una correlación muy alta es decir que tienen mucha similitud el puntaje compuesto junto con el puntaje total
# Con las gráficas se pudo concluir que conforme los alumnos aumentan sus calificaciones los padres también tienen sus ingresos ligeramente aumentados a comparación de los alumnos con puntaje más bajo esto se puede notar en la última gráfica dónde los padres que tenían mayor estudio eran los que sus hijos tenían de las calificaciones más altas, esto no quiere decir que se confirme que los alumnos que tienen más solvencia económica les vaya mejor, para eso se debería utilizar una técnica de minería que se va a mencionar en el trabajo a futuro, entonces se llegó a la conclusión que de los factores que serían importantes para poder escoger a los alumnos para la selección de becas sería que los padres fueran de los menores ingresos económicos pero también es importante checar que los alumnos seleccionados sean de los que tienen mejores calificaciones a comparación de otros alumnos. Otro punto importante aclarar fue que el gobierno tendría qué efectúar esas becas en un tiempo promedio entre 3 y 6 años, puesto que la mayoria de ellos tienen ese tiempo promedio para graduarse, entonces se tomara en consideración que por generación se tendría que sustentar una beca económica a los alumnos durante el tiempo ya establecido
#
# Entonces de cuerdo al onda alisado anteriormente viviendo los factores económicos y académicos de los alumnos sea decidido que uno de los factores primordiales sería ofrecer becas a los alumnos cuyo ingreso de padres sea menor a 80000 puesto que se llegó a la conclusión de que entre más ingresos tienen los padres tienen un poco de mayores calificaciones por lo cual se ofertará la beca para los alumnos que tengan el mejor promedio con la condición de que sus padres estén con ingresos no mayores a 80,000
#
# ---
# Trabajo A Futuro:
#
# Para nuestro trabajo futuro una vez analizados los puntos teniendo en cuenta que los factores a realizar son los de las calificaciones de los alumnos más altas con los alumnos cuyos ingresos sean menores a 80,000, se tiene que para la problemática del objetivo 3 sería seleccionar al 10% de la población es decir una vez ya teniendo en cuenta el objetivo principal que se mencionó anteriormente Y el objetivo secundario que se dice que hay un promedio de que los alumnos reciban beca por un promedio de 3años a 6años
# La técnica qué se debe utilizar sería la técnica de máquinas de soporte puesto que como la definición misma lo explica  sus aplicaciones es para la selección de variables que nuestro caso nosotros las utilizaremos con los alumnos con mayores calificaciones lo cual quiere decir que se van a no tomar en cuenta los alumnos cuyo ingresos sean mayores 80,000 y cuyo puntaje dónde entre los 20 y 25 aproximadamente, para lo cual se van a separar datos
